# %%
import pandas as pd
import pyodbc

# %%
sales_go = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=C:/Users/Jonat/Downloads/GO-databases schoon/go_sales_schoon.accdb;')

# %%
product = pd.read_sql("SELECT * FROM product", sales_go)
product_type = pd.read_sql("SELECT * FROM product_type", sales_go)
return_item = pd.read_sql("SELECT DISTINCT * FROM returned_item", sales_go)
klant = pd.read_sql("SELECT * FROM sales_retailer_site", sales_go)
return_reason = pd.read_sql("SELECT * FROM return_reason", sales_go)
country = pd.read_sql("SELECT * FROM sales_country", sales_go)
order_details = pd.read_sql("SELECT * FROM order_details", sales_go)
order_header = pd.read_sql("SELECT * FROM order_header", sales_go)
order_method = pd.read_sql("SELECT * FROM order_method", sales_go)
product_line = pd.read_sql("SELECT * FROM product_line", sales_go)
# Out:
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product = pd.read_sql("SELECT * FROM product", sales_go)
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_type = pd.read_sql("SELECT * FROM product_type", sales_go)
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return_item = pd.read_sql("SELECT DISTINCT * FROM returned_item", sales_go)
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   klant = pd.read_sql("SELECT * FROM sales_retailer_site", sales_go)
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return_reason = pd.read_sql("SELECT * FROM return_reason", sales_go)
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   country = pd.read_sql("SELECT * FROM sales_country", sales_go)
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_details = pd.read_sql("SELECT * FROM order_details", sales_go)
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_header = pd.read_sql("SELECT * FROM order_header", sales_go)
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   order_method = pd.read_sql("SELECT * FROM order_method", sales_go)
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_12276\1052911171.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_line = pd.read_sql("SELECT * FROM product_line", sales_go)

# %%
productfull = pd.merge(product, product_type)
productfull = pd.merge(productfull, product_line)
productfull
# Out:
#     PRODUCT_NUMBER INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST MARGIN  \
# 0               53         10-1-2021                 8           28.55    .28
# 1               54         10-1-2021                 8           35.33    .33
# 2               55         10-1-2021                 8               4     .5
# 3               56         10-1-2021                 8               9     .5
# 4               50         10-1-2021                 8               2     .5
# ..             ...               ...               ...             ...    ...
# 110             37          5-3-2013                 5           28.75    .37
# 111             38          5-3-2013                 5              20    .33
# 112             39          5-3-2013                 5           40.63    .37
# 113             40         15-2-2011                 5           17.97    .28
# 114             41         10-1-2021                 5           24.62    .23
#
#      PRODUCT_IMAGE LANGUAGE                  PRODUCT_NAME  \
# 0    P53ME2CA8.jpg       EN         Firefly Climbing Lamp
# 1    P54ME2CA8.jpg       EN               Firefly Charger
# 2    P55ME2CA8.jpg       EN  Firefly Rechargeable Battery
# 3    P56ME2CA8.jpg       EN             Granite Chalk Bag
# 4    P50ME2CA8.jpg       EN             Granite Carabiner
# ..             ...      ...                           ...
# 110  P37CE1LT5.jpg       EN               EverGlow Double
# 111  P38CE1LT5.jpg       EN             EverGlow Kerosene
# 112  P39CE1LT5.jpg       EN               EverGlow Butane
# 113  P40CE1LT5.jpg       EN                 EverGlow Lamp
# 114  P41CE1LT5.jpg       EN               Flicker Lantern
#
#                                            DESCRIPTION PRODUCT_LINE_CODE  \
# 0    This climbing lamp is water-resistant. It come...                 2
# 1    Power charger for the Firefly Climbing Lamp. T...                 2
# 2    Rechargeable battery pack for the Firefly Clim...                 2
# 3    Nylon web bag perfect for holding several stic...                 2
# 4    Made from 12 mm rod stock aluminum and a radiu...                 2
# ..                                                 ...               ...
# 110  Light output approximates a 175 W bulb. Double...                 1
# 111  One of the most dependable sources of light in...                 1
# 112  Adjustable brightness control with auto igniti...                 1
# 113  Perfect for in your tent, this lamp comes with...                 1
# 114  Simple to use, just requires a candle to be in...                 1
#
#           PRODUCT_TYPE_EN           PRODUCT_LINE_EN
# 0    Climbing Accessories  Mountaineering Equipment
# 1    Climbing Accessories  Mountaineering Equipment
# 2    Climbing Accessories  Mountaineering Equipment
# 3    Climbing Accessories  Mountaineering Equipment
# 4    Climbing Accessories  Mountaineering Equipment
# ..                    ...                       ...
# 110              Lanterns         Camping Equipment
# 111              Lanterns         Camping Equipment
# 112              Lanterns         Camping Equipment
# 113              Lanterns         Camping Equipment
# 114              Lanterns         Camping Equipment
#
# [115 rows x 12 columns]

# %%
returnfull = pd.merge(return_item, return_reason)
returnfull = pd.merge(returnfull, order_details[['ORDER_DETAIL_CODE', 'ORDER_NUMBER']])
returnfull = pd.merge(returnfull, order_header [['ORDER_NUMBER', 'RETAILER_NAME']])
returnfull = pd.merge(returnfull, order_details[['ORDER_DETAIL_CODE', 'PRODUCT_NUMBER']])
returnfull = pd.merge(returnfull, productfull)
returnfull
# Out:
#     RETURN_CODE          RETURN_DATE ORDER_DETAIL_CODE RETURN_REASON_CODE  \
# 0          1491    1-8-2021 04:10:24             84858                  5
# 1          1918   25-4-2022 22:56:33             98653                  5
# 2          1566   28-7-2020 09:24:15             47783                  4
# 3          1917  15-10-2022 17:45:46             98648                  3
# 4          1502   27-8-2022 20:52:27             85850                  5
# ..          ...                  ...               ...                ...
# 701        2287   11-5-2021 06:15:02             60732                  1
# 702        2298  14-12-2021 11:28:50            100250                  1
# 703        2344   18-8-2022 17:42:13             50150                  1
# 704        2347   28-8-2020 12:30:24            109838                  1
# 705        2363   10-7-2020 12:30:24            105449                  1
#
#     RETURN_QUANTITY   RETURN_DESCRIPTION_EN ORDER_NUMBER  \
# 0                 8  Unsatisfactory product         7446
# 1                22  Unsatisfactory product         8239
# 2                20   Wrong product shipped         1415
# 3                28   Wrong product ordered         8317
# 4                30  Unsatisfactory product         7457
# ..              ...                     ...          ...
# 701               2       Defective product         5121
# 702               6       Defective product         9254
# 703               8       Defective product         1363
# 704               6       Defective product         9467
# 705               8       Defective product         8825
#
#                                      RETAILER_NAME PRODUCT_NUMBER  \
# 0                     Ausr³stungshaus Globetrotter              6
# 1                                Beter Buitenleven              6
# 2                                Falcon Outfitters              6
# 3                                Beter Buitenleven              6
# 4                      Outdoor-Fachgeschõft M³ller             29
# ..                                             ...            ...
# 701  ArtÝculos de Campismo El Aquila, S.A. de C.V.             51
# 702                              Naranco de Bulnes             43
# 703                                   Ultra Sports             90
# 704                                   Preben's T°y             93
# 705                        Chen Yu Enterprise Co.,             91
#
#     INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST MARGIN  \
# 0            5-3-2013                 1           85.11    .28
# 1            5-3-2013                 1           85.11    .28
# 2            5-3-2013                 1           85.11    .28
# 3            5-3-2013                 1           85.11    .28
# 4            5-3-2013                 4           41.18     .4
# ..                ...               ...             ...    ...
# 701         10-1-2021                 8              35     .5
# 702         10-1-2021                 6          126.66    .33
# 703         15-2-2011                15             2.5    .63
# 704         15-2-2011                16               2     .6
# 705         15-2-2011                16               2     .6
#
#       PRODUCT_IMAGE LANGUAGE               PRODUCT_NAME  \
# 0     P06CE1CG1.jpg       EN  TrailChef Deluxe Cook Set
# 1     P06CE1CG1.jpg       EN  TrailChef Deluxe Cook Set
# 2     P06CE1CG1.jpg       EN  TrailChef Deluxe Cook Set
# 3     P06CE1CG1.jpg       EN  TrailChef Deluxe Cook Set
# 4     P29CE1PK4.jpg       EN       Canyon Mule Carryall
# ..              ...      ...                        ...
# 701   P51ME2CA8.jpg       EN              Granite Belay
# 702   P42ME2RP6.jpg       EN              Husky Rope 60
# 703  P86OP4IR15.jpg       EN          BugShield Extreme
# 704  P91OP4SS16.jpg       EN             Sun Shelter 15
# 705  P91OP4SS16.jpg       EN                Sun Blocker
#
#                                            DESCRIPTION PRODUCT_LINE_CODE  \
# 0    Cascade set features 1, 2, and 3 liter pots wi...                 1
# 1    Cascade set features 1, 2, and 3 liter pots wi...                 1
# 2    Cascade set features 1, 2, and 3 liter pots wi...                 1
# 3    Cascade set features 1, 2, and 3 liter pots wi...                 1
# 4    This pack has a large capacity, perfect for ca...                 1
# ..                                                 ...               ...
# 701  The Granite Belay is an ingenious single rope ...                 2
# 702  11 mm diameter standard rope. Length: 60 m.  W...                 2
# 703  Highest amount of the active ingredient, 38%, ...                 4
# 704          SPF 15 protects against all harmful rays.                 4
# 705  Sun Blocker is waterproof and lasts up to eigh...                 4
#
#           PRODUCT_TYPE_EN           PRODUCT_LINE_EN
# 0            Cooking Gear         Camping Equipment
# 1            Cooking Gear         Camping Equipment
# 2            Cooking Gear         Camping Equipment
# 3            Cooking Gear         Camping Equipment
# 4                   Packs         Camping Equipment
# ..                    ...                       ...
# 701  Climbing Accessories  Mountaineering Equipment
# 702                  Rope  Mountaineering Equipment
# 703     Insect Repellents        Outdoor Protection
# 704             Sunscreen        Outdoor Protection
# 705             Sunscreen        Outdoor Protection
#
# [706 rows x 20 columns]

# %%
Final_Table = returnfull
Final_Table
# Out:
#     RETURN_CODE          RETURN_DATE ORDER_DETAIL_CODE RETURN_REASON_CODE  \
# 0          1491    1-8-2021 04:10:24             84858                  5
# 1          1918   25-4-2022 22:56:33             98653                  5
# 2          1566   28-7-2020 09:24:15             47783                  4
# 3          1917  15-10-2022 17:45:46             98648                  3
# 4          1502   27-8-2022 20:52:27             85850                  5
# ..          ...                  ...               ...                ...
# 701        2287   11-5-2021 06:15:02             60732                  1
# 702        2298  14-12-2021 11:28:50            100250                  1
# 703        2344   18-8-2022 17:42:13             50150                  1
# 704        2347   28-8-2020 12:30:24            109838                  1
# 705        2363   10-7-2020 12:30:24            105449                  1
#
#     RETURN_QUANTITY   RETURN_DESCRIPTION_EN ORDER_NUMBER  \
# 0                 8  Unsatisfactory product         7446
# 1                22  Unsatisfactory product         8239
# 2                20   Wrong product shipped         1415
# 3                28   Wrong product ordered         8317
# 4                30  Unsatisfactory product         7457
# ..              ...                     ...          ...
# 701               2       Defective product         5121
# 702               6       Defective product         9254
# 703               8       Defective product         1363
# 704               6       Defective product         9467
# 705               8       Defective product         8825
#
#                                      RETAILER_NAME PRODUCT_NUMBER  \
# 0                     Ausr³stungshaus Globetrotter              6
# 1                                Beter Buitenleven              6
# 2                                Falcon Outfitters              6
# 3                                Beter Buitenleven              6
# 4                      Outdoor-Fachgeschõft M³ller             29
# ..                                             ...            ...
# 701  ArtÝculos de Campismo El Aquila, S.A. de C.V.             51
# 702                              Naranco de Bulnes             43
# 703                                   Ultra Sports             90
# 704                                   Preben's T°y             93
# 705                        Chen Yu Enterprise Co.,             91
#
#     INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST MARGIN  \
# 0            5-3-2013                 1           85.11    .28
# 1            5-3-2013                 1           85.11    .28
# 2            5-3-2013                 1           85.11    .28
# 3            5-3-2013                 1           85.11    .28
# 4            5-3-2013                 4           41.18     .4
# ..                ...               ...             ...    ...
# 701         10-1-2021                 8              35     .5
# 702         10-1-2021                 6          126.66    .33
# 703         15-2-2011                15             2.5    .63
# 704         15-2-2011                16               2     .6
# 705         15-2-2011                16               2     .6
#
#       PRODUCT_IMAGE LANGUAGE               PRODUCT_NAME  \
# 0     P06CE1CG1.jpg       EN  TrailChef Deluxe Cook Set
# 1     P06CE1CG1.jpg       EN  TrailChef Deluxe Cook Set
# 2     P06CE1CG1.jpg       EN  TrailChef Deluxe Cook Set
# 3     P06CE1CG1.jpg       EN  TrailChef Deluxe Cook Set
# 4     P29CE1PK4.jpg       EN       Canyon Mule Carryall
# ..              ...      ...                        ...
# 701   P51ME2CA8.jpg       EN              Granite Belay
# 702   P42ME2RP6.jpg       EN              Husky Rope 60
# 703  P86OP4IR15.jpg       EN          BugShield Extreme
# 704  P91OP4SS16.jpg       EN             Sun Shelter 15
# 705  P91OP4SS16.jpg       EN                Sun Blocker
#
#                                            DESCRIPTION PRODUCT_LINE_CODE  \
# 0    Cascade set features 1, 2, and 3 liter pots wi...                 1
# 1    Cascade set features 1, 2, and 3 liter pots wi...                 1
# 2    Cascade set features 1, 2, and 3 liter pots wi...                 1
# 3    Cascade set features 1, 2, and 3 liter pots wi...                 1
# 4    This pack has a large capacity, perfect for ca...                 1
# ..                                                 ...               ...
# 701  The Granite Belay is an ingenious single rope ...                 2
# 702  11 mm diameter standard rope. Length: 60 m.  W...                 2
# 703  Highest amount of the active ingredient, 38%, ...                 4
# 704          SPF 15 protects against all harmful rays.                 4
# 705  Sun Blocker is waterproof and lasts up to eigh...                 4
#
#           PRODUCT_TYPE_EN           PRODUCT_LINE_EN
# 0            Cooking Gear         Camping Equipment
# 1            Cooking Gear         Camping Equipment
# 2            Cooking Gear         Camping Equipment
# 3            Cooking Gear         Camping Equipment
# 4                   Packs         Camping Equipment
# ..                    ...                       ...
# 701  Climbing Accessories  Mountaineering Equipment
# 702                  Rope  Mountaineering Equipment
# 703     Insect Repellents        Outdoor Protection
# 704             Sunscreen        Outdoor Protection
# 705             Sunscreen        Outdoor Protection
#
# [706 rows x 20 columns]

# %%
Final_Table = Final_Table.drop(["ORDER_NUMBER", "RETURN_DATE", "ORDER_DETAIL_CODE", "PRODUCTION_COST", "MARGIN", "LANGUAGE", "PRODUCT_IMAGE", "DESCRIPTION"], axis = 1)
Final_Table
# Out:
#     RETURN_CODE RETURN_REASON_CODE RETURN_QUANTITY   RETURN_DESCRIPTION_EN  \
# 0          1491                  5               8  Unsatisfactory product
# 1          1918                  5              22  Unsatisfactory product
# 2          1566                  4              20   Wrong product shipped
# 3          1917                  3              28   Wrong product ordered
# 4          1502                  5              30  Unsatisfactory product
# ..          ...                ...             ...                     ...
# 701        2287                  1               2       Defective product
# 702        2298                  1               6       Defective product
# 703        2344                  1               8       Defective product
# 704        2347                  1               6       Defective product
# 705        2363                  1               8       Defective product
#
#                                      RETAILER_NAME PRODUCT_NUMBER  \
# 0                     Ausr³stungshaus Globetrotter              6
# 1                                Beter Buitenleven              6
# 2                                Falcon Outfitters              6
# 3                                Beter Buitenleven              6
# 4                      Outdoor-Fachgeschõft M³ller             29
# ..                                             ...            ...
# 701  ArtÝculos de Campismo El Aquila, S.A. de C.V.             51
# 702                              Naranco de Bulnes             43
# 703                                   Ultra Sports             90
# 704                                   Preben's T°y             93
# 705                        Chen Yu Enterprise Co.,             91
#
#     INTRODUCTION_DATE PRODUCT_TYPE_CODE               PRODUCT_NAME  \
# 0            5-3-2013                 1  TrailChef Deluxe Cook Set
# 1            5-3-2013                 1  TrailChef Deluxe Cook Set
# 2            5-3-2013                 1  TrailChef Deluxe Cook Set
# 3            5-3-2013                 1  TrailChef Deluxe Cook Set
# 4            5-3-2013                 4       Canyon Mule Carryall
# ..                ...               ...                        ...
# 701         10-1-2021                 8              Granite Belay
# 702         10-1-2021                 6              Husky Rope 60
# 703         15-2-2011                15          BugShield Extreme
# 704         15-2-2011                16             Sun Shelter 15
# 705         15-2-2011                16                Sun Blocker
#
#     PRODUCT_LINE_CODE       PRODUCT_TYPE_EN           PRODUCT_LINE_EN
# 0                   1          Cooking Gear         Camping Equipment
# 1                   1          Cooking Gear         Camping Equipment
# 2                   1          Cooking Gear         Camping Equipment
# 3                   1          Cooking Gear         Camping Equipment
# 4                   1                 Packs         Camping Equipment
# ..                ...                   ...                       ...
# 701                 2  Climbing Accessories  Mountaineering Equipment
# 702                 2                  Rope  Mountaineering Equipment
# 703                 4     Insect Repellents        Outdoor Protection
# 704                 4             Sunscreen        Outdoor Protection
# 705                 4             Sunscreen        Outdoor Protection
#
# [706 rows x 12 columns]
